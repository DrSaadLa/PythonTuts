# %% [markdown]
# # <u><center><font size=6, color="#458B74"> Introduction to Keras API</font></u>

# %%
#=======================================================================#
#       Topic:     Deep Learning with Keras                             #    
#       Objective: This notebook is prepared to practice                #
#                  building deep neural network models using keras      #
#                                                                       #
#        Author:  Dr. Saad Laouadi                                      #
#                                                                       #
#=======================================================================#

# %%
#=======================================================================#
#.                   Import the necessary modules and tools
#=======================================================================#








import warnings
warnings.filterwarnings("ignore") 
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # <u><center><font size=6, color="#458B74">Sequential Regression Model</font></u>

# %% [markdown]
# ### Building Neural Network Models
#
# 1. Build a sequential model for a regression problem for the diagram shown bellow:

# %% [markdown]
# ![ex1.png](attachment:ex1.png)

# %%
# Import the Sequential model and Dense layer


# Create a Sequential model


# Add an input layer and a hidden layer 


# Add an output layer


# Summarize your model

# %% [markdown]
# 2. Build a sequential model for a regression problem for the diagram shown below:

# %% [markdown]
# ![ex2-2.png](attachment:ex2-2.png)

# %%
# Create a Sequential model


# Add an input layer and a hidden layer 


# Add an output layer


# Summarize your model

# %% [markdown]
# 3. Build a regression model for the next diagram

# %% [markdown]
# ![three_six_one-2.png](attachment:three_six_one-2.png)

# %%
# Create a Sequential model


# Add an input layer and a hidden layer 


# Add an output layer


# Summarize your model

# %% [markdown]
# 4. Build a regression for the next diagram

# %% [markdown]
# ![ex3.png](attachment:ex3.png)

# %%
# Create a Sequential model


# Add an input layer and a hidden layer 


# Add an output layer


# Summarize your model

# %% [markdown]
# ## Adding More Layers
#
# Build a regression model for the next diagram

# %% [markdown]
# ![neural_net2.jpeg](attachment:neural_net2.jpeg)

# %%
# Create a Sequential model


# Add an input layer and a hidden layer 


# Add a second hidder layer 


# Add an output layer


# Summarize your model

# %% [markdown]
# ### Challenge
#
# Build a regression model for the next diagram

# %% [markdown]
# ![Dense-Neural-Network-2.png](attachment:Dense-Neural-Network-2.png)

# %%
# Create a Sequential model

# Add an input layer and a hidden layer 


# Add a second hidder layer 


# Add an output layer


# Summarize your model

# %% [markdown]
# # <u><center><font size=6, color="#458B74">Binary Classification</font></u>

# %% [markdown]
# ## Building Binary Classification Models with Keras
#
# - Build a sequential model for a binary classification problem for the next diagram

# %% [markdown]
# ![three_six_one.png](attachment:three_six_one.png)

# %%
from keras.models import Sequential
from keras.layers import Dense

# Instantiate a Sequential model


# Build the input and hidden layer


# Add an output layer for a binary output

# Check the summary

# %% [markdown]
# # <u><center><font size=6, color="#458B74">Multi-class Classification</font></u>

# %% [markdown]
# ### Multi-Class Classification with keras
#
#  - Build a multi-class classification for the diagram shown bellow:

# %% [markdown]
# ![three_six_two_2.png](attachment:three_six_two_2.png)

# %%
# Import pandas and to_categorical (Suppose you haven't done that befor)
import pandas 
from tensorflow.keras.utils import to_categorical
# Read in the data
#data = pd.read_csv('data.csv')
# Convert the target to categorical
#data['target'] = pd.Categorical(data['target']) 

# One-hot encode the target variable
# y = to_categorial(data['target'])
# This is for a later use when building a model with data.
# ========================================================


# Instantiate a sequential model 

# Add a hidden layer


# Add a dense output layer


# Check the model summary

# %% [markdown]
# ### Build a model for the diagram bellow

# %% [markdown]
# ![three_twelve_three.png](attachment:three_twelve_three.png)

# %%
# Instantiate a sequential model 

# Add a hidden layer


# Add a dense output layer

# Check the model summary

# %% [markdown]
# ## Challenges
#
# ### Challenge 01
#
#  - Build a model for the next diagram

# %% [markdown]
# ![denseNet.png](attachment:denseNet.png)

# %%
# Build a sequential model

# %% [markdown]
# ### Challenge 02:
#
#  - Build a model for the diagram bellow:

# %% [markdown]
# ![images.jpeg](attachment:images.jpeg)

# %%
# Build a sequential model 


# add the output layer


# Check the model summary

# %% [markdown]
# * * *

# %% [markdown]
# # <u><center><font size=6, color="#458B74">Model Compilation</font></u>

# %% [markdown]
# ## 1. Compiling Regression Models

# %%
# Create a regression then compile it using mse loss and adam optimizer
# --------------------------------------------------------------------
# Create a Sequential model
model = Sequential()

# Add an input layer and a hidden layer 
model.add(Dense(6, activation="relu", input_shape=(3,)))

# Add an output layer
model.add(Dense(1))

# Compile the model


# Check the loss function used

# %%
# Create a regression then compile it using mae loss and adam optimizer
# --------------------------------------------------------------------
# Create a Sequential model
model = Sequential()

# Add an input layer and a hidden layer 
model.add(Dense(4, activation="relu", input_shape=(3,)))

# Add a second hidder layer 
model.add(Dense(4, activation="relu"))

# Add an output layer
model.add(Dense(1))

# Compile the model

# %% [markdown]
# * * *

# %% [markdown]
# ## 1. Compiling Classification Models

# %%
# Create and compile a binary classification model using sgd optimizer
# ---------------------------------------------------------------------
# Instantiate a Sequential model
model = Sequential()

# Build the input and hidden layer
model.add(Dense(6, activation ="tanh", input_shape = (3,)))

# Add an output layer for a binary output


# Compile the model 


# Check the model loss function

# %%
# Create and compile a binary classification model using "adam" optimizer
# ---------------------------------------------------------------------
# Instantiate a sequential model for a 4-class label problem
model = Sequential() 

# Add a hidden layer
model.add(Dense(12, activation='relu', input_shape=(3,)))

# Add a dense output layer


# Compile the model


# Check the model loss function

# %% [markdown]
# * * *

# %% [markdown]
# # <u><center><font size=6, color="#458B74">Regression Project</font></u>

# %%
#===================================================#
#            This is a small project to show
#            how to build a neural network model
#            using keras.
#====================================================#

wages = pd.read_csv('wages.csv')

wages.describe()

# %%
# Extract the predictors 


# Check the shape of the predictors

# %%
# Extract the target variable


# Check the shape

# %%
# =======================================================#
#          Building a regression model
# =======================================================#
# Import necessary modules (if not already done)

import keras
from keras.layers import Dense
from keras.models import Sequential


# Instantiate a sequential model
# -----------------------------


# Add the the input layer with 64 units and relu activation function
# ------------------------------------------------------------------


# Add the second layer with 32 units
#-----------------------------------


# Add the output layer
# --------------------

# %%
# Print the summary of the model
# --------------------------

# %%
# Compile the model using "adam" and mse loss function
# ------------------------------------------------------

# %%
# Fit the model using:
#.    1. batch size = 32
#.    2. set verbose to 1
#     3. set epochs to 25
# ========================

# %%
# Print the model history

# %%
# Plot the history

# %%
# Save the model using h5 extension
# ---------------------------------

# %%
# Import load_model
from tensorflow.keras.models import load_model

# Load the model back


# Check the summary to verify
